# %% [markdown]
# Hola, en este módulo de desarrollarán los retos propuestos

# %% [markdown]
# Reto 1

# %%
pasos = 50 # se define la cantidad de pasos
print("creando tortuga simulada que da...", pasos, "pasos") # se imprime la cantidad de pasos
print("-" * pasos + "m>") # se imprime de manera gráfica los pasos dados
# Out:
# creando tortuga simulada que da... 50 pasos
# --------------------------------------------------m>

# %% [markdown]
# Reto 2
# se creará el rastro de una tortuga moviéndose hacia abajo usando únicamente print() e input().

# %%
pasos = 5 
for i in range(pasos): #se usa bucle  para que imprima "|" cuantas veces pase hasta que cumpla la condición de pasos
    print("|")   
print("V") #al salir del bucle, finalmente imprime la figura de la tortuga

print("La tortuga bajó",pasos,"pasos.")
# Out:
# |
# |
# |
# |
# |
# V
# La tortuga bajó 5 pasos.

# %%
pasos_y = 15 # se define la cantidad de pasos en Y
pasos_x = 10 # se define la cantidad de pasos en X

print("-" * pasos_x + ">") # se imprime la línea horizontal

for i in range(pasos_y): 
    print(" " * pasos_x + "|")   

print(" " * pasos_x + "V") 


pasos_totales = pasos_x + pasos_y

print("La tortuga caminó", pasos_x,"pasos.")
print("La tortuga bajó", pasos_y, "pasos.")
# Out:
# ---------->
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           |
#           V
# La tortuga caminó 10 pasos.
# La tortuga bajó 15 pasos.

# %%
pasos_adelante = int(input("¿Cuántos pasos avanza la tortuga? "))
pasos_abajo = int(input("¿Cuántos pasos baja la tortuga? "))

posicion_x = 0
posicion_y = 0

def adelante(pasos):
    global posicion_x, posicion_y
    print(" " * posicion_x + "-" * pasos + ">")
    posicion_x += pasos

def abajo(pasos):
    global posicion_x, posicion_y

    for i in range(pasos):
        print(" " * posicion_x + "|")
    
    print(" " * posicion_x + "V")

    posicion_y += pasos

adelante(pasos_adelante)
abajo(pasos_abajo)
# Out:
# ---------->
#           |
#           |
#           |
#           |
#           |
#           V
